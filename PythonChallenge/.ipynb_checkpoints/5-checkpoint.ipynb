# %% [markdown]
# ***```url: http://www.pythonchallenge.com/pc/def/peak.html```***

# %%
import pickle, requests

# %%
url = 'http://www.pythonchallenge.com/pc/def/banner.p'

# %%
r = requests.get(url)

# %%
pickle_file = pickle.loads(bytes(r.text, encoding='utf8'))

# %%
pickle_file
# Out:
# [[(' ', 95)],
#  [(' ', 14), ('#', 5), (' ', 70), ('#', 5), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 6),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 9),
#   ('#', 3),
#   (' ', 7),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 10),
#   ('#', 3),
#   (' ', 7),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 3),
#   ('#', 3),
#   (' ', 3),
#   ('#', 2),
#   (' ', 4),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
#   (' ', 5),
#   ('#', 2),
#   (' ', 2),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
#   (' ', 3),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
#   (' ', 5),
#   ('#', 3),
#   (' ', 2),
#   ('#', 3),
#   (' ', 5),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 2),
#   ('#', 3),
#   (' ', 5),
#   ('#', 3),
#   (' ', 2),
#   ('#', 5),
#   (' ', 4),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 3),
#   ('#', 4),
#   (' ', 4),
#   ('#', 5),
#   (' ', 4),
#   ('#', 4),
#   (' ', 2),
#   ('#', 5),
#   (' ', 4),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 5),
#   ('#', 3),
#   (' ', 3),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 1),
#   ('#', 3),
#   (' ', 11),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 3),
#   (' ', 4),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 1),
#   ('#', 3),
#   (' ', 11),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 10),
#   ('#', 3),
#   (' ', 4),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 3),
#   (' ', 7),
#   ('#', 3),
#   (' ', 2),
#   ('#', 4),
#   (' ', 1)],
#  [('#', 4),
#   (' ', 11),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 5),
#   ('#', 2),
#   (' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 1),
#   ('#', 4),
#   (' ', 7),
#   ('#', 3),
#   (' ', 2),
#   ('#', 4),
#   (' ', 1)],
#  [('#', 4),
#   (' ', 11),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 3),
#   ('#', 10),
#   (' ', 4),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 1),
#   ('#', 14),
#   (' ', 2),
#   ('#', 4),
#   (' ', 1)],
#  [('#', 4),
#   (' ', 11),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 3),
#   (' ', 4),
#   ('#', 4),
#   (' ', 4),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 1),
#   ('#', 4),
#   (' ', 12),
#   ('#', 4),
#   (' ', 1)],
#  [('#', 4),
#   (' ', 11),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 1),
#   ('#', 4),
#   (' ', 5),
#   ('#', 3),
#   (' ', 4),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 1),
#   ('#', 4),
#   (' ', 12),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 1),
#   ('#', 3),
#   (' ', 11),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 1),
#   ('#', 4),
#   (' ', 5),
#   ('#', 3),
#   (' ', 4),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 3),
#   (' ', 12),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 2),
#   ('#', 3),
#   (' ', 6),
#   ('#', 2),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 3),
#   (' ', 4),
#   ('#', 4),
#   (' ', 4),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 6),
#   ('#', 2),
#   (' ', 3),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 2),
#   (' ', 3),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 3),
#   ('#', 11),
#   (' ', 3),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 2),
#   ('#', 4),
#   (' ', 5),
#   ('#', 4),
#   (' ', 4),
#   ('#', 3),
#   (' ', 4),
#   ('#', 2),
#   (' ', 4),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 6),
#   ('#', 3),
#   (' ', 5),
#   ('#', 6),
#   (' ', 4),
#   ('#', 5),
#   (' ', 4),
#   ('#', 2),
#   (' ', 4),
#   ('#', 4),
#   (' ', 1),
#   ('#', 6),
#   (' ', 4),
#   ('#', 11),
#   (' ', 4),
#   ('#', 5),
#   (' ', 6),
#   ('#', 3),
#   (' ', 6),
#   ('#', 6)],
#  [(' ', 95)]]

# %%
res = '\n'.join(''.join(col[0] * col[1] for col in row) for row in pickle_file)

# %%
print(res)
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
#   ###     ###  #####    ####   ###   ####    #####    ####  #####    ####   ###     ###   ####
#  ###           ####     ####   ###    ###    ####     ####  ####     ####  ###      ####  ####
#  ###           ####     ####          ###    ####     ####  ####     ####  ###       ###  ####
# ####           ####     ####     ##   ###    ####     ####  ####     #### ####       ###  ####
# ####           ####     ####   ##########    ####     ####  ####     #### ##############  ####
# ####           ####     ####  ###    ####    ####     ####  ####     #### ####            ####
# ####           ####     #### ####     ###    ####     ####  ####     #### ####            ####
#  ###           ####     #### ####     ###    ####     ####  ####     ####  ###            ####
#   ###      ##  ####     ####  ###    ####    ####     ####  ####     ####   ###      ##   ####
#    ###    ##   ####     ####   ###########   ####     ####  ####     ####    ###    ##    ####
#       ###     ######    #####    ##    #### ######    ###########    #####      ###      ######

# %% [markdown]
# ***```next url: http://www.pythonchallenge.com/pc/def/channel.html```***
